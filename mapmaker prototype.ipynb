# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

df = pd.read_csv("map.csv", sep="\t", index_col=0)

df.iloc[:,0].fillna(0, inplace=True)
df.iloc[:,1].fillna(0, inplace=True)
df.iloc[:,2].fillna(0, inplace=True)

df["mūla"] = df["mūla"].astype('int')
df["aṭṭhakathā"] = df["aṭṭhakathā"].astype('int')
df["ṭīkā"] = df["ṭīkā"].astype('int')

# df.iloc[:,0].astype("str")
# df.iloc[:,1].astype(str)
# df.iloc[:,2].astype("int")
# df.iloc[:,3].astype(int)
# df.iloc[:,4].astype(int)

display (df)
# Out:
#                               mūla  aṭṭhakathā  ṭīkā
# vinaya - pārājika                4          12    34
# vinaya - pācittiya               7          14    12
# vinaya - mahāvagga               3          15     4
# vinaya - cūlavagga               9           3     5
# sutta - dīgha                   12           8   234
# sutta - majjhima                 3           5   234
# sutta - saṃyutta                 5           4    23
# sutta - aṅguttara                6           6   645
# sutta - khuddaka                 8          78    45
# abhidhamma - dhammasaṅgaṇī       0          23     1
# abhidhamma - vibhaṅga            1          45     4
# abhidhamma - dhātukathā          2          56     5
# abhidhamma - puggalapaññatti     3          76    34
# abhidhamma - kathāvatthu         5           7    23
# abhidhamma - yamaka              6          88    23
# abhidhamma - paṭṭhāna            8          12   234
# aññā                             3           1     1

# %%
# Python program to generate heatmap which 
# represents panda dataframe in color-coding schemes
# along with values mentioned in each cell
  
# import required libraries
# import pandas as pd
import seaborn as sns
  
# Defining figure size  
# for the output plot 
fig, ax = plt.subplots(figsize = (12, 7))
  
# # # Defining index for the dataframe
# idx = ['1', '2', '3', '4']
  
# # # Defining columns for the dataframe
# cols = list('ABCD')
  
# Entering values in the index and columns  
# and converting them into a panda dataframe
# df = pd.DataFrame([[10, 20, 30, 40], [50, 30, 8, 15],
#                    [25, 14, 41, 8], [7, 14, 21, 28]],
#                    columns = cols, index = idx)
  
# Displaying dataframe as an heatmap 
# with diverging colourmap as RdYlGn
sns.heatmap(df, cmap ='Blues', linewidths = 0.10, annot = True)

bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (17.5, -0.5)

# %%
df.style.background_gradient(axis=None, cmap='Blues')
# Out:
# <style type="text/css">
# #T_9e6f0_row0_col0, #T_9e6f0_row2_col0, #T_9e6f0_row2_col2, #T_9e6f0_row3_col1, #T_9e6f0_row3_col2, #T_9e6f0_row5_col0, #T_9e6f0_row5_col1, #T_9e6f0_row6_col0, #T_9e6f0_row6_col1, #T_9e6f0_row10_col2, #T_9e6f0_row11_col2, #T_9e6f0_row12_col0, #T_9e6f0_row13_col0, #T_9e6f0_row16_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_9e6f0_row0_col1, #T_9e6f0_row1_col2, #T_9e6f0_row4_col0, #T_9e6f0_row15_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_9e6f0_row0_col2, #T_9e6f0_row12_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_9e6f0_row1_col0, #T_9e6f0_row7_col0, #T_9e6f0_row7_col1, #T_9e6f0_row13_col1, #T_9e6f0_row14_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_9e6f0_row1_col1, #T_9e6f0_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_9e6f0_row3_col0, #T_9e6f0_row4_col1, #T_9e6f0_row8_col0, #T_9e6f0_row15_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# ...
