# %%
import os
import pandas as pd


datadir = "/home/bhikkhu/Bodhirasa/Dropbox/dpd/word frequency maps/output/data/"
output_file = open ("output/000.txt", "w")
output_file = open ("output/000.txt", "a")
allzero = []
problems = []

x=0
for filename in os.listdir(datadir):
	if x % 5000 == 0:
		print (x, filename)
	df = pd.read_csv(f"{datadir}{filename}", sep=",", index_col=0, header=None) 
	if (df[1] == 0).all():
		open ("output/000.txt", "a") 
			f.write(f"{zero}\n")
			allzero.append(filename)
	x+=1

output_file.close()
	
# print(f"{allzero=}")
# # print(f"{problems=}")
# Out:
# 0 bhāsana.csv
# 5000 corosi.csv
# 10000 anānujānanta.csv
# 15000 indriyavagga.csv
# 20000 avirūḷhichanda.csv
# 25000 mahājanamajjha.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18674/476429131.py in <module>
#      11         if x % 5000 == 0:
#      12                 print (x, filename)
# ---> 13         df = pd.read_csv(f"{datadir}{filename}", sep=",", index_col=0, header=None)
#      14         if (df[1] == 0).all():
#      15                 with open ("output/000.txt", "w") as f:
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
print(allzero)
# Out:
# ['āsavakkhayañāṇa.csv', 'anusotapaṭisotaṃ.csv', 'golikā.csv', 'cūḷapanthakasutta.csv', 'anussavakathā.csv', 'ninnādasadda.csv', 'bhūsenta.csv', 'aṭṭhila.csv', 'padhūpeti.csv', 'gandhūhana.csv', 'sapita.csv', 'pariyogāhi.csv', 'sippaṭṭhāyatana.csv', 'aminā.csv', 'pacari.csv', 'kambalīya.csv', 'yāgī.csv', 'apakantati.csv', 'paṭipahiṇitvā.csv', 'samijjhitvā.csv', 'jalukā.csv', 'aṇḍūpaka 1.csv', 'khajjakabhājaka.csv', 'accīmant.csv', 'tapavana.csv', 'viparītasaññācittadiṭṭhi.csv', 'usuyyati.csv', 'dukkhavinaya.csv', 'pesanika.csv', 'appatikkha 1.csv', 'gamaṭṭhāna.csv', 'saṃkilissitvā.csv', 'parihasi.csv', 'ajjuposatha.csv', 'muddāpesi.csv', 'nīvārabhakka.csv', 'nimmiṇi.csv', 'nisādī.csv', 'vināma.csv', 'gaṇabandhandhika.csv', 'nighaṃsita.csv', 'samudīretvā.csv', 'vidaṃsaka.csv', 'pācikā.csv', 'randhesi.csv', 'catutthābhabbaṭṭhānasutta.csv', 'meghiyasutta 2.csv', 'kopāntara.csv', 'nalinī.csv', 'ekachiggala.csv', 'abhiññatā.csv', 'bhijjadhamma.csv', 'acc.csv', 'mukharatā.csv', 'ubbattita.c
# ...
